# %% [markdown]
# <a href="https://colab.research.google.com/github/eBilie/Portfolio/blob/main/Fetal_Health_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
 # To load the dataset
df = pd.read_csv('fetal_health.csv')

# To rename DataFrame

fhd = df

# To display the first few lines of the data set
fhd.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
# To check for missing values
missing_values = fhd.isnull().sum()
print("Missing values in each column:\n", missing_values)


# To display summary statistics
fhd.describe()
# Out:
# Missing values in each column:
#  baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# ...

# %%
# To display the first few rows

fhd.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
#To check data types


fhd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
# To summary of the numerical columns

fhd.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
# Check for missing values

missing_values = fhd.isnull().sum()

print(missing_values)
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
# Analyze categorical variables

categorical_columns = fhd.select_dtypes(include=['object']).columns

for col in categorical_columns:

    print(fhd[col].value_counts())

# %%
fhd.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
# Plot Boxplot for numerical features

plt.figure(figsize=(20, 10))

for i, feature in enumerate(numerical_features):
    plt.subplot(num_rows, num_cols, i+1)
    sns.boxplot(data=fhd, y=feature, color='skyblue')

    plt.title(f'Box Plot of {feature}')

plt.tight_layout()

plt.show()

# %%
# To plot histograms for numerical features

plt.figure(figsize=(20, num_rows * 5))

for i, feature in enumerate(numerical_features):
    plt.subplot(num_rows, num_cols, i+1)
    sns.histplot(fhd[feature], kde=True, color=palette[i % len(palette)])
    plt.title(f'Distribution of {feature}')

plt.tight_layout()

plt.suptitle('Histograms of Numerical Features', y=1.02)

plt.show()

# %%
for i, feature in enumerate(numerical_features):
    plt.subplot(4, 4, i+1)
    sns.histplot(fetal_health_data[feature], kde=True, color=sns.color_palette('Set2')[i % 10])
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.suptitle('Customized Histograms of Numerical Features', y=1.02)
plt.show()

# %%
plt.figure(figsize=(20, 10))
for i, feature in enumerate(numerical_features):
    plt.subplot(4, 4, i+1)
    sns.boxplot(data=fhd, y=feature, color='skyblue')
    plt.title(f'Box Plot of {feature}')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-559c2ce70e8e> in <cell line: 2>()
#       1 plt.figure(figsize=(20, 10))
#       2 for i, feature in enumerate(numerical_features):
# ----> 3     plt.subplot(4, 4, i+1)
#       4     sns.boxplot(data=fhd, y=feature, color='skyblue')
#       5     plt.title(f'Box Plot of {feature}')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1321
#    1322     # First, search for an existing subplot with a matching spec.
# -> 1323     key = SubplotSpec._from_subplot_args(fig, args)
#    1324
#    1325     for ax in fig.axes:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     596         else:
#     597             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# ...

# %%
# To set preferred colour palette
colours=["#54bebe","#dc9cbf", "#a01b68"]


# To create a count plot for the 'fetal_health' column
sns.countplot(x='fetal_health', data=fhd, palette=colours)

# To add titles and labels for clarity
plt.title('Count of Fetal Health Outcomes')
plt.xlabel('Fetal Health Category')
plt.ylabel('Count')

# Display the plot
plt.show()
# Out:
# <ipython-input-18-40a8342f5225>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='fetal_health', data=fhd, palette=colours)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(fhd['fetal_health'], bins=30, kde=True)
plt.title('Distribution of Fetal Health')
plt.xlabel('Fetal Health')
plt.ylabel('Baseline Value')
plt.show()

# %%
# Box plot to identify outliers

plt.figure(figsize=(10, 6))
sns.boxplot(x=fhd['fetal_health'])
plt.title('Box Plot for Fetal Health')
plt.xlabel('Fetal health')
plt.show()

# %%
# Correlation matrix

correlation_matrix = fhd.corr()

# Heatmap for visualizing correlations

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')

plt.show()

# %%
# Count plot for a categorical variable

plt.figure(figsize=(10, 6))
sns.countplot(x='fetal_health', data=fhd, palette='Set2')
plt.title('Count Plot of Fetal Health Outcomes')

plt.xlabel('Fetal Health Category')

plt.ylabel('Count')

plt.show()
# Out:
# <ipython-input-48-4bb33fcf6ffe>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='fetal_health', data=fhd, palette='Set2')

# %%
# Implot: to show linear relationship between Fetal Movement and Abnormal Shorterm Variabilty

sns.lmplot(x='fetal_movement', y='abnormal_short_term_variability',data=fhd, hue='fetal_health', palette='Set2')
plt.title('Linear Relationship between Fetal Movement and Abnormal Shorterm Variabilty')

plt.xlabel('Fetal Movement')

plt.ylabel('Abnormal Shorterm Variabilty')

plt.show()

# %%
#  Stripplot for Uterine Contractions value by fetal health outcomes


plt.figure(figsize=(10, 6))

sns.stripplot(x='fetal_health', y='uterine_contractions', data=fhd, hue='fetal_health', palette='Set2', jitter=True, legend=False)

plt.title('Strip Plot of Uterine Contractions by Fetal Health Outcomes')

plt.xlabel('Fetal Health Category')
plt.ylabel('Uterine Contractions')

plt.show()
